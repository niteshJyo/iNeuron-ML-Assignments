# %% [markdown]
# ### In this assignment students have to transform iris data into 3 dimensions and plot a 3d chart with transformed dimensions and colour each data point with specific class.

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import pandas as pd

# %%
data = pd.read_csv("iris.csv")
data = data.drop(["Id"], axis = 1)

# %%
data
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
# fig 01

fig = plt.figure(figsize = (10,10))
ax = fig.add_subplot(111,projection='3d')
ax.set_xlabel('SepalLength', fontsize = 15)
ax.set_ylabel('SepalWidth', fontsize = 15)
ax.set_zlabel('PetalLength', fontsize = 15)
ax.set_title('IRIS', fontsize = 20)

Species = ['Iris-setosa', 'Iris-versicolor', 'Iris-virginica']
colors = ['r', 'g', 'b']
for species, color in zip(Species,colors):
    indicesToKeep = data['Species'] == species
    ax.scatter(data.loc[indicesToKeep, 'SepalLengthCm']
               , data.loc[indicesToKeep, 'SepalWidthCm']
               , data.loc[indicesToKeep, 'PetalLengthCm']
               , c = color
               , s = 50)
    
ax.legend(Species)
ax.grid()
plt.show()

# %%
# fig 02

fig = plt.figure(figsize = (10,10))
ax = fig.add_subplot(111,projection='3d')
ax.set_xlabel('SepalLength', fontsize = 15)
ax.set_ylabel('SepalWidth', fontsize = 15)
ax.set_zlabel('PetalWidth', fontsize = 15)
ax.set_title('IRIS', fontsize = 20)

Species = ['Iris-setosa', 'Iris-versicolor', 'Iris-virginica']
colors = ['r', 'g', 'b']
for species, color in zip(Species,colors):
    indicesToKeep = data['Species'] == species
    ax.scatter(data.loc[indicesToKeep, 'SepalLengthCm']
               , data.loc[indicesToKeep, 'SepalWidthCm']
               , data.loc[indicesToKeep, 'PetalWidthCm']
               , c = color
               , s = 50)
    
ax.legend(Species)
ax.grid()
plt.show()

# %%
# fig 03

fig = plt.figure(figsize = (10,10))
ax = fig.add_subplot(111,projection='3d')
ax.set_xlabel('PetalLength', fontsize = 15)
ax.set_ylabel('SepalWidth', fontsize = 15)
ax.set_zlabel('PetalWidth', fontsize = 15)
ax.set_title('IRIS', fontsize = 20)

Species = ['Iris-setosa', 'Iris-versicolor', 'Iris-virginica']
colors = ['r', 'g', 'b']
for species, color in zip(Species,colors):
    indicesToKeep = data['Species'] == species
    ax.scatter(data.loc[indicesToKeep, 'PetalLengthCm']
               , data.loc[indicesToKeep, 'SepalWidthCm']
               , data.loc[indicesToKeep, 'PetalWidthCm']
               , c = color
               , s = 50)
    
ax.legend(Species)
ax.grid()
plt.show()

# %%
# fig 04

fig = plt.figure(figsize = (10,10))
ax = fig.add_subplot(111,projection='3d')
ax.set_xlabel('PetalLength', fontsize = 15)
ax.set_ylabel('SepalLength', fontsize = 15)
ax.set_zlabel('PetalWidth', fontsize = 15)
ax.set_title('IRIS', fontsize = 20)

Species = ['Iris-setosa', 'Iris-versicolor', 'Iris-virginica']
colors = ['r', 'g', 'b']
for species, color in zip(Species,colors):
    indicesToKeep = data['Species'] == species
    ax.scatter(data.loc[indicesToKeep, 'PetalLengthCm']
               , data.loc[indicesToKeep, 'SepalLengthCm']
               , data.loc[indicesToKeep, 'PetalWidthCm']
               , c = color
               , s = 50)
    
ax.legend(Species)
ax.grid()
plt.show()
